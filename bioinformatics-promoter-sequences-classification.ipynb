# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
#import kagglehub
#samira1992_promoter_or_not_bioinformatics_dataset_path = kagglehub.dataset_download('samira1992/promoter-or-not-bioinformatics-dataset')

#print('Data source import complete.')

# %%
# Imports
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
import sys
import pandas as pd
import re
import timeit
import io
import IPython.display as display
from PIL import Image
from torch.utils.data import (TensorDataset, DataLoader, RandomSampler,
                              SequentialSampler)

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, roc_curve

import kagglehub
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import clear_output


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def load_data_kaggle():
    """
    This script imports promoter sequence data from Kaggle. 
    Ensure that you have the required Kaggle credentials and packages installed before running.
    """

    promoter_ = pd.read_csv('/kaggle/input/promoter-or-not-bioinformatics-dataset/promoter.csv')
    non_promoter_ = pd.read_csv('/kaggle/input/promoter-or-not-bioinformatics-dataset/non_promoter.csv')
    patterns_table_ = pd.read_csv('/kaggle/input/promoter-or-not-bioinformatics-dataset/bendability.tsv', header=None, names=['codon','score'], sep='\t')
    promoter_ = promoter_.to_numpy()
    non_promoter_ = non_promoter_.to_numpy()
    
    return promoter_, non_promoter_, patterns_table_

def load_data_local():
    """
    This script imports promoter sequence data from Kaggle. 
    Ensure that you have the required Kaggle credentials and packages installed before running.
    """
    samira1992_promoter_or_not_bioinformatics_dataset_path = kagglehub.dataset_download('samira1992/promoter-or-not-bioinformatics-dataset')
    print('Data source import complete.')
    
    promoter_ = pd.read_csv(os.path.join(samira1992_promoter_or_not_bioinformatics_dataset_path, 'promoter.csv'))
    non_promoter_ = pd.read_csv(os.path.join(samira1992_promoter_or_not_bioinformatics_dataset_path, 'non_promoter.csv'))
    patterns_table_ = pd.read_csv(os.path.join(samira1992_promoter_or_not_bioinformatics_dataset_path, 'bendability.tsv'), header=None, names=['codon','score'], sep='\t')
    promoter_ = promoter_.to_numpy()
    non_promoter_ = non_promoter_.to_numpy()
    
    return promoter_, non_promoter_, patterns_table_

def tokenize_stride1(sequences, max_length = 250, k=3):
    """
    Tokenizes sequences into k-mers with a stride of 1.

    Args:
        sequences (numpy.ndarray): Array of sequences to tokenize.
        max_length (int, optional): Maximum length of sequences. Defaults to 250.
        k (int, optional): Length of k-mers. Defaults to 3.

    Returns:
        numpy.ndarray: Array of k-mers with a stride of 1.
    """

    # Adjust sequences to maximum length and pad with 'N'
    adjusted_seqs = [seq[:max_length].ljust(max_length, "N").lower() for seq in sequences.flatten()]

    # Tokenize sequences into k-mers with a stride of 1
    return np.array([[seq[i:i+k] for i in range(len(seq) - k + 1)] for seq in adjusted_seqs])

def seq_encoding(sequences_kmerized, codons):
    """
    Encodes sequences into numerical representations.

    Args:
        sequences_kmerized (numpy.ndarray): Array of k-mers.
        codons (dict): Dictionary of codons and their corresponding numerical representations.

    Returns:
        numpy.ndarray: Array of encoded sequences.
    """
    encoded_codons=[]
    for codon in sequences_kmerized:
        if codon not in codons.keys():
          if isinstance(codons['atg'], np.ndarray):
            encoded_codons.append(np.zeros(64))
          else:
            encoded_codons.append(0)

        else:
            encoded_codons.append(codons[codon])

    if isinstance(encoded_codons[0], np.ndarray):
      return np.array(encoded_codons).T.astype(np.float32)
    else:
      return np.array(encoded_codons).astype(np.int32)

def data_loader(train_inputs, val_inputs, train_labels, val_labels,
                batch_size=10):
    """
    Convert train and validation sets to torch.Tensors and load them to DataLoader.

    Args:
        train_inputs (numpy.ndarray): Training input data.
        val_inputs (numpy.ndarray): Validation input data.
        train_labels (numpy.ndarray): Training labels.
        val_labels (numpy.ndarray): Validation labels.
        batch_size (int, optional): Batch size for DataLoader. Defaults to 10.

    Returns:
        tuple: Tuple containing training and validation DataLoaders.
    """

    # Convert data type to torch.Tensor
    train_inputs, val_inputs, train_labels, val_labels =\
    tuple(torch.tensor(data) for data in
          [train_inputs, val_inputs, train_labels, val_labels])

    # Create DataLoader for training data
    train_data = TensorDataset(train_inputs, train_labels)
    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

    # Create DataLoader for testing data
    val_data = TensorDataset(val_inputs, val_labels)
    val_sampler = SequentialSampler(val_data)
    val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=batch_size)

    return train_dataloader, val_dataloader

class Net(nn.Module):
    """
    A neural network model for predicting promoter sequences.

    Args:
        embedding_dim (int, optional): Dimension of the embedding layer. Defaults to 32.
        num_codons (int, optional): Number of codons. Defaults to 65.
        params (list, optional): List of parameters for the neural network architecture. Defaults to [248,128,6,3,1,(3, 2, 1),128,10,6,3,1,(3,2,1),70].

    Attributes:
        embedding (nn.Embedding): Embedding layer.
        norm (nn.BatchNorm1d): Batch normalization layer.
        linear_relu_stack (nn.Sequential): Sequential container for the neural network layers.
    """
    def __init__(self, embedding_dim=32, num_codons=65, params = [248,128,6,3,1,(3, 2, 1),128,10,6,3,1,(3,2,1),70]):  #num of codons + unknown
        super().__init__()

        self.embedding = nn.Embedding(num_codons, embedding_dim)
        self.norm = nn.BatchNorm1d(embedding_dim)

        self.linear_relu_stack = nn.Sequential(
        nn.Conv1d(in_channels=params[0],
                out_channels=params[1],
                kernel_size=params[2],
                stride=params[3],
                padding=params[4]),
        nn.BatchNorm1d(params[1]),
        nn.ReLU(),
        nn.MaxPool1d(*params[5]),
        nn.Dropout(p=0.3),

        nn.Conv1d(in_channels=params[1],
                  out_channels=params[6],
                  kernel_size=params[7],
                  stride=params[8],
                  padding=params[9]),
        nn.BatchNorm1d(params[6]),
        nn.ReLU(),
        nn.MaxPool1d(*params[10]),
        nn.Flatten(),
        nn.Linear(params[11], round(params[11]/2)),
        nn.ReLU(),
        nn.Dropout(p=0.5),
        nn.Linear(round(params[11]/2), 1))
        #nn.ReLU(),
        #nn.Linear(round(params[11]/16), 1))
        #nn.ReLU(),
        #nn.Linear(round(params[7]/4), round(params[7]/16)),
        #nn.ReLU(),
        #nn.Linear(round(params[7]/16), 1)
        #nn.Sigmoid())

        #for layer in self.linear_relu_stack:
        #    if isinstance(layer, nn.Conv1d):
        #        torch.nn.init.xavier_normal_(layer.weight)
        #    elif isinstance(layer, nn.Linear):
        #        torch.nn.init.xavier_normal_(layer.weight)

    def forward(self, x, verbose=False):

        if verbose:
            print(f"Input shape: {x.shape}")  # Debugging: Print input shape
            x = self.embedding(x)
            x = torch.transpose(x, 1, 2)
            x = self.norm(x)
            for layer in self.linear_relu_stack:
              print(f"Before {layer.__class__.__name__}: {x.shape}")
              x = layer(x)
              print(f"After {layer.__class__.__name__}: {x.shape}")
            return x

        else:
          x = self.embedding(x)
          x = torch.transpose(x, 1, 2)
          x = self.norm(x)
          return self.linear_relu_stack(x)

def plot_metrics(train_loss, test_loss, test_acc, precision, recall, auc):
    """
    Plots training and testing metrics for a machine learning model.

    Args:
        train_loss (list): List of training loss values.
        test_loss (list): List of testing loss values.
        test_acc (list): List of testing accuracy values.
        precision (list): List of precision values.
        recall (list): List of recall values.
        auc (tuple): Tuple containing the AUC-ROC value and the FPR and TPR values.

    Returns:
        None
    """
    epochs = range(1, len(train_loss) + 1)

    plots = []

    # Create a figure
    fig, axes = plt.subplots(1, 4, figsize=(12, 4))

    # Plot loss curve
    axes[0].plot(epochs, train_loss, label='Train Loss')
    axes[0].plot(epochs, test_loss, label='Test Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].set_title('Loss Curve')
    axes[0].set_ylim(0,1.2 * max(max(train_loss), max(test_loss)))
    axes[0].legend()

    # Plot accuracy curve
    axes[1].plot(epochs, test_acc, label='Test Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_title('Accuracy Curve')
    axes[1].set_ylim(0, 1)
    axes[1].legend()

    # Plot precision-recall curve
    axes[2].plot(recall, precision, label='Precision-Recall Curve')
    axes[2].set_xlabel('Recall')
    axes[2].set_ylabel('Precision')
    axes[2].set_title('Precision-Recall Curve')
    axes[2].set_ylim(0, 1)
    axes[2].set_xlim(0, 1)
    axes[2].legend()

    auc_roc, (fpr, tpr) = auc
    axes[3].plot(fpr, tpr, label=f"AUC={auc_roc:.4f}")
    axes[3].set_xlabel('FPR')
    axes[3].set_ylabel('TPR')
    axes[3].set_title('AUC-ROC Curve')
    axes[3].set_ylim(0, 1)
    axes[3].set_xlim(0, 1)
    axes[3].legend()

    plt.tight_layout()

    # Save plots to list

    buf = io.BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    plt.close(fig)

    return buf


def train_loop(dataloader, model, loss_fn, optimizer, batch_size = 100, verbose=False):
    """
    Trains a model for one epoch.

    Args:
        dataloader (DataLoader): DataLoader for the training data.
        model (nn.Module): Neural network model to be trained.
        loss_fn (nn.Module): Loss function to be used.
        optimizer (nn.Module): Optimizer to be used.
        batch_size (int, optional): Batch size. Defaults to 100.
        verbose (bool, optional): Whether to print verbose output. Defaults to False.

    Returns:
        float: Average training loss for the epoch.
    """
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    losses = []
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss_value, correct = 0, 0

    for i, batch in enumerate(dataloader, 0):
        # Compute prediction and loss
        X, y = batch[0].to(device), batch[1].to(device).float()

        #print(f"Inputs dtype: {X.dtype}, Labels dtype: {y.dtype}")
        #print(f"Inputs length: {len(X)}, Labels length: {len(y)}")

        pred = model(X, verbose)
        pred = pred.view(-1)
        train_loss = loss_fn(pred, y)
        train_loss_value += train_loss.item()

        # Backpropagation
        train_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if i % 100 == 0:
            loss_batch100, current = train_loss.item(), i * batch_size + len(X)
            print(f"Train loss 100th: {loss_batch100:>0.2f}  [{current:>5d}/{size:>5d}]")

    # calculate per epoch
    train_loss_value /= num_batches
    print(f"Avg Train Loss: {train_loss_value:>0.2f}")

    return train_loss_value

def test_loop(dataloader, model, loss_fn, sig_threshold):
    
    """
    Evaluates a model on a test dataset for one epoch.

    Args:
        dataloader (DataLoader): DataLoader for the test data.
        model (nn.Module): Neural network model to be evaluated.
        loss_fn (nn.Module): Loss function to be used.
        sig_threshold (float): Threshold for sigmoid activation function.

    Returns:
        tuple: Test loss, accuracy, precision, recall, AUC-ROC, and FPR and TPR values.
    """
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    all_preds, all_labels, all_probs = [], [], []

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for i, batch in enumerate(dataloader, 0):

            # Compute prediction and loss
            X, y = batch[0].to(device), batch[1].to(device).float()
            pred = model(X)
            pred = pred.squeeze()

            test_loss += loss_fn(pred, y).item()

            probs = torch.sigmoid(pred)
            predicted_labels = (probs >= sig_threshold).float()
            correct += (predicted_labels == y).type(torch.float).sum().item()
            all_probs.extend(probs.cpu().numpy())

            # Store predictions and true labels for metric calculation
            all_preds.extend(predicted_labels.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    test_loss /= num_batches
    accuracy = correct / size

    #Precision/Recall and F1-score calculation
    precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)

    auc_roc = roc_auc_score(all_labels, all_probs)
    fpr, tpr, _ = roc_curve(all_labels, all_probs)

    print(f"Test Metrics: \n Accuracy: {(100 * accuracy):>0.1f}%, "
          f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}, "
          f"Avg loss: {test_loss:>8f} \n")

    return test_loss, accuracy, precision, recall, auc_roc, (fpr, tpr)

def epochs_loop(train_dataloader, test_dataloader, model, batch_size=64, epochs=1, lr=0.01, momentum=0.9, decay=0.0, sig_threshold=0.5, train_debug=False):
    """
    Trains a model for multiple epochs.

    Args:
        train_dataloader (DataLoader): DataLoader for the training data.
        test_dataloader (DataLoader): DataLoader for the test data.
        model (nn.Module): Neural network model to be trained.
        batch_size (int, optional): Batch size. Defaults to 64.
        epochs (int, optional): Number of epochs. Defaults to 1.
        lr (float, optional): Learning rate. Defaults to 0.01.
        momentum (float, optional): Momentum for SGD optimizer. Defaults to 0.9.
        decay (float, optional): Weight decay for optimizer. Defaults to 0.0.
        sig_threshold (float, optional): Threshold for sigmoid activation function. Defaults to 0.5.
        train_debug (bool, optional): Whether to print debug output during training. Defaults to False.

    Returns:
        tuple: Lists of training loss, test loss, and plot data.
    """
    train_loss_epochs, test_loss_epochs, precision_epochs, recall_epochs, acc_epochs, auc_epochs = [], [], [], [], [], []
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=decay)
    #optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=decay)

    # start timer
    loop_time = timeit.default_timer()
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")

        train_loss = train_loop(dataloader = train_dataloader,
                                model = model,
                                loss_fn = loss_fn,
                                optimizer = optimizer,
                                batch_size = batch_size,
                                verbose=train_debug)

        test_loss, accuracy, precision, recall, auc_roc, roc_curve_data = test_loop(test_dataloader, model, loss_fn, sig_threshold)

        # To plot
        train_loss_epochs.append(train_loss)
        test_loss_epochs.append(test_loss)
        precision_epochs.append(precision)
        recall_epochs.append(recall)
        acc_epochs.append(accuracy)
        # stop timer
        print('Time {}'.format(np.round((timeit.default_timer() - loop_time),2)))

    plot = plot_metrics(train_loss=train_loss_epochs,
                        test_loss=test_loss_epochs,
                        test_acc=acc_epochs,
                        precision=precision_epochs,
                        recall=recall_epochs,
                        auc=(auc_roc, roc_curve_data))

    return train_loss_epochs, test_loss_epochs, plot

# %%
# Load data
promoter, non_promoter, codon_score = load_data_kaggle()

#promoter, non_promoter, codon_score = load_data_local()

# Create codon score dictionary
codon_score_dict = dict(zip(codon_score['codon'], codon_score['score']))

# Create sequences and labels
all_raw_sequences = np.concatenate([promoter, non_promoter])
all_labels = labels = np.concatenate([
    np.ones(len(promoter), dtype=int),      #1 promoter
    np.zeros(len(non_promoter), dtype=int)  #0 non-promoter
])

# Tokenize sequences
sequences_kmerized = tokenize_stride1(all_raw_sequences)

# one-hot
#codon_to_one_hot = {codon: np.eye(64)[i] for i, codon in enumerate(codon_score_dict)}
#one_hot_seqs = [seq_encoding(seq, codons=codon_to_one_hot) for seq in sequences_kmerized]

# random_token
codon_to_num = {codon: i+1 for i, codon in enumerate(codon_score_dict)}
random_token_seqs = [seq_encoding(seq, codons=codon_to_num) for seq in sequences_kmerized]

# %%
# Split data
train_inputs, test_inputs, train_labels, test_labels = train_test_split(
    random_token_seqs, all_labels, train_size=0.8, test_size=0.2, random_state=42)

# Create DataLoaders
train_dataloader, test_dataloader = data_loader(train_inputs, test_inputs, train_labels, test_labels, batch_size=64)

# %%
# Creating net and training

#Test Decay
mode1 = [0.001, 0.9, 1e-2, 20, 64, 0.5]
mode2 = [0.001, 0.9, 1e-3, 20, 64, 0.5]
mode3 = [0.001, 0.9, 1e-4, 20, 64, 0.5]
mode4 = [0.001, 0.9, 1e-5, 20, 64, 0.5]
mode5 = [0.001, 0.9, 1e-6, 20, 64, 0.5]

#Test LR
mode6 = [0.01, 0.9, 1e-5, 20, 64, 0.5]
mode7 = [0.005, 0.9, 1e-5, 20, 64, 0.5]
mode8 = [0.0001, 0.9, 1e-5, 20, 64, 0.5]

list_plots=[]
for mode in [mode1, mode2, mode3, mode4, mode5, mode6, mode7, mode8]:
    lr, momentum, decay, epochs, batch_size, sigthr = mode

    variable_data = {
        'lr': lr,
        'momentum': momentum,
        'decay': decay,
        'epochs': epochs,
        'batch_size': batch_size,
        'sigthr': sigthr,
        'arch_params': [32, 128,8,4,1,(3, 2, 1), 256,8,4,1,(3, 2, 1), 1024]}

    # Model
    model = Net(params=variable_data['arch_params'])
    model.to(device)

    # Training
    train_loss, test_loss, plots = epochs_loop(train_dataloader=train_dataloader,
                                              test_dataloader=test_dataloader,
                                              model=model,
                                              epochs=variable_data['epochs'],
                                              lr=variable_data['lr'],
                                              momentum=variable_data['momentum'],
                                              decay=variable_data['decay'],
                                              sig_threshold= variable_data['sigthr'],
                                              train_debug=False)

    list_plots.append(plots)
# Out:
# Epoch 1
# -------------------------------
# Train loss 100th: 0.74  [   64/48000]
# Train loss 100th: 0.36  [ 6464/48000]
# Train loss 100th: 0.36  [12864/48000]
# Train loss 100th: 0.35  [19264/48000]
# Train loss 100th: 0.36  [25664/48000]
# Train loss 100th: 0.26  [32064/48000]
# Train loss 100th: 0.20  [38464/48000]
# Train loss 100th: 0.31  [44864/48000]
# Avg Train Loss: 0.34
# Test Metrics:
#  Accuracy: 88.9%, Precision: 0.8975, Recall: 0.8876, F1-score: 0.8879, Avg loss: 0.293754
#
# Time 3.11
# Epoch 2
# -------------------------------
# Train loss 100th: 0.26  [   64/48000]
# Train loss 100th: 0.42  [ 6464/48000]
# Train loss 100th: 0.30  [12864/48000]
# Train loss 100th: 0.29  [19264/48000]
# Train loss 100th: 0.27  [25664/48000]
# Train loss 100th: 0.28  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.23  [44864/48000]
# Avg Train Loss: 0.29
# Test Metrics:
#  Accuracy: 90.1%, Precision: 0.9015, Recall: 0.9014, F1-score: 0.9012, Avg loss: 0.275097
#
# Time 6.15
# Epoch 3
# -------------------------------
# Train loss 100th: 0.25  [   64/48000]
# Train loss 100th: 0.27  [ 6464/48000]
# Train loss 100th: 0.31  [12864/48000]
# Train loss 100th: 0.27  [19264/48000]
# Train loss 100th: 0.30  [25664/48000]
# Train loss 100th: 0.36  [32064/48000]
# Train loss 100th: 0.25  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.28
# Test Metrics:
#  Accuracy: 91.0%, Precision: 0.9107, Recall: 0.9097, F1-score: 0.9099, Avg loss: 0.243795
#
# Time 9.17
# Epoch 4
# -------------------------------
# Train loss 100th: 0.19  [   64/48000]
# Train loss 100th: 0.38  [ 6464/48000]
# Train loss 100th: 0.30  [12864/48000]
# Train loss 100th: 0.37  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.19  [32064/48000]
# Train loss 100th: 0.30  [38464/48000]
# Train loss 100th: 0.24  [44864/48000]
# Avg Train Loss: 0.27
# Test Metrics:
#  Accuracy: 91.2%, Precision: 0.9141, Recall: 0.9120, F1-score: 0.9123, Avg loss: 0.233024
#
# Time 12.18
# Epoch 5
# -------------------------------
# Train loss 100th: 0.24  [   64/48000]
# Train loss 100th: 0.33  [ 6464/48000]
# Train loss 100th: 0.21  [12864/48000]
# Train loss 100th: 0.16  [19264/48000]
# Train loss 100th: 0.25  [25664/48000]
# Train loss 100th: 0.29  [32064/48000]
# Train loss 100th: 0.35  [38464/48000]
# Train loss 100th: 0.16  [44864/48000]
# Avg Train Loss: 0.26
# Test Metrics:
#  Accuracy: 91.4%, Precision: 0.9152, Recall: 0.9137, F1-score: 0.9140, Avg loss: 0.228483
#
# Time 15.18
# Epoch 6
# -------------------------------
# Train loss 100th: 0.30  [   64/48000]
# Train loss 100th: 0.15  [ 6464/48000]
# Train loss 100th: 0.31  [12864/48000]
# Train loss 100th: 0.23  [19264/48000]
# Train loss 100th: 0.27  [25664/48000]
# Train loss 100th: 0.26  [32064/48000]
# Train loss 100th: 0.26  [38464/48000]
# Train loss 100th: 0.21  [44864/48000]
# Avg Train Loss: 0.25
# Test Metrics:
#  Accuracy: 91.7%, Precision: 0.9176, Recall: 0.9170, F1-score: 0.9172, Avg loss: 0.224085
#
# Time 18.32
# Epoch 7
# -------------------------------
# Train loss 100th: 0.13  [   64/48000]
# Train loss 100th: 0.20  [ 6464/48000]
# Train loss 100th: 0.24  [12864/48000]
# Train loss 100th: 0.15  [19264/48000]
# Train loss 100th: 0.29  [25664/48000]
# Train loss 100th: 0.18  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.19  [44864/48000]
# Avg Train Loss: 0.25
# Test Metrics:
#  Accuracy: 91.8%, Precision: 0.9187, Recall: 0.9174, F1-score: 0.9176, Avg loss: 0.223734
#
# Time 21.3
# Epoch 8
# -------------------------------
# Train loss 100th: 0.21  [   64/48000]
# Train loss 100th: 0.30  [ 6464/48000]
# Train loss 100th: 0.20  [12864/48000]
# Train loss 100th: 0.36  [19264/48000]
# Train loss 100th: 0.28  [25664/48000]
# Train loss 100th: 0.24  [32064/48000]
# Train loss 100th: 0.28  [38464/48000]
# Train loss 100th: 0.29  [44864/48000]
# Avg Train Loss: 0.25
# Test Metrics:
#  Accuracy: 91.6%, Precision: 0.9164, Recall: 0.9164, F1-score: 0.9164, Avg loss: 0.224110
#
# Time 24.29
# Epoch 9
# -------------------------------
# Train loss 100th: 0.19  [   64/48000]
# Train loss 100th: 0.25  [ 6464/48000]
# Train loss 100th: 0.17  [12864/48000]
# Train loss 100th: 0.16  [19264/48000]
# Train loss 100th: 0.26  [25664/48000]
# Train loss 100th: 0.28  [32064/48000]
# Train loss 100th: 0.21  [38464/48000]
# Train loss 100th: 0.32  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 91.6%, Precision: 0.9168, Recall: 0.9163, F1-score: 0.9164, Avg loss: 0.225257
#
# Time 27.26
# Epoch 10
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.33  [ 6464/48000]
# Train loss 100th: 0.31  [12864/48000]
# Train loss 100th: 0.32  [19264/48000]
# Train loss 100th: 0.26  [25664/48000]
# Train loss 100th: 0.23  [32064/48000]
# Train loss 100th: 0.34  [38464/48000]
# Train loss 100th: 0.33  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 91.6%, Precision: 0.9168, Recall: 0.9157, F1-score: 0.9159, Avg loss: 0.221443
#
# Time 30.24
# Epoch 11
# -------------------------------
# Train loss 100th: 0.29  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.36  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.24  [25664/48000]
# Train loss 100th: 0.30  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.16  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 91.6%, Precision: 0.9194, Recall: 0.9156, F1-score: 0.9160, Avg loss: 0.220016
#
# Time 33.24
# Epoch 12
# -------------------------------
# Train loss 100th: 0.16  [   64/48000]
# Train loss 100th: 0.22  [ 6464/48000]
# Train loss 100th: 0.16  [12864/48000]
# Train loss 100th: 0.19  [19264/48000]
# Train loss 100th: 0.17  [25664/48000]
# Train loss 100th: 0.34  [32064/48000]
# Train loss 100th: 0.16  [38464/48000]
# Train loss 100th: 0.23  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 91.5%, Precision: 0.9161, Recall: 0.9145, F1-score: 0.9148, Avg loss: 0.220397
#
# Time 36.24
# Epoch 13
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.28  [ 6464/48000]
# Train loss 100th: 0.18  [12864/48000]
# Train loss 100th: 0.18  [19264/48000]
# Train loss 100th: 0.14  [25664/48000]
# Train loss 100th: 0.31  [32064/48000]
# Train loss 100th: 0.29  [38464/48000]
# Train loss 100th: 0.34  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.0%, Precision: 0.9203, Recall: 0.9196, F1-score: 0.9198, Avg loss: 0.217414
#
# Time 39.24
# Epoch 14
# -------------------------------
# Train loss 100th: 0.40  [   64/48000]
# Train loss 100th: 0.14  [ 6464/48000]
# Train loss 100th: 0.22  [12864/48000]
# Train loss 100th: 0.29  [19264/48000]
# Train loss 100th: 0.28  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.22  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 91.8%, Precision: 0.9188, Recall: 0.9180, F1-score: 0.9182, Avg loss: 0.216572
#
# Time 42.23
# Epoch 15
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.23  [ 6464/48000]
# Train loss 100th: 0.25  [12864/48000]
# Train loss 100th: 0.39  [19264/48000]
# Train loss 100th: 0.24  [25664/48000]
# Train loss 100th: 0.17  [32064/48000]
# Train loss 100th: 0.15  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 91.9%, Precision: 0.9189, Recall: 0.9184, F1-score: 0.9185, Avg loss: 0.215665
#
# Time 45.24
# Epoch 16
# -------------------------------
# Train loss 100th: 0.28  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.15  [12864/48000]
# Train loss 100th: 0.21  [19264/48000]
# Train loss 100th: 0.27  [25664/48000]
# Train loss 100th: 0.23  [32064/48000]
# Train loss 100th: 0.30  [38464/48000]
# Train loss 100th: 0.24  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.1%, Precision: 0.9222, Recall: 0.9204, F1-score: 0.9207, Avg loss: 0.215825
#
# Time 48.27
# Epoch 17
# -------------------------------
# Train loss 100th: 0.21  [   64/48000]
# Train loss 100th: 0.30  [ 6464/48000]
# Train loss 100th: 0.16  [12864/48000]
# Train loss 100th: 0.30  [19264/48000]
# Train loss 100th: 0.24  [25664/48000]
# Train loss 100th: 0.23  [32064/48000]
# Train loss 100th: 0.34  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.0%, Precision: 0.9218, Recall: 0.9200, F1-score: 0.9203, Avg loss: 0.210388
#
# Time 51.34
# Epoch 18
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.45  [ 6464/48000]
# Train loss 100th: 0.22  [12864/48000]
# Train loss 100th: 0.27  [19264/48000]
# Train loss 100th: 0.33  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.29  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.1%, Precision: 0.9213, Recall: 0.9208, F1-score: 0.9209, Avg loss: 0.211537
#
# Time 54.31
# Epoch 19
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.25  [ 6464/48000]
# Train loss 100th: 0.24  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.23  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.28  [38464/48000]
# Train loss 100th: 0.27  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.0%, Precision: 0.9204, Recall: 0.9203, F1-score: 0.9203, Avg loss: 0.212863
#
# Time 57.33
# Epoch 20
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.38  [ 6464/48000]
# Train loss 100th: 0.23  [12864/48000]
# Train loss 100th: 0.42  [19264/48000]
# Train loss 100th: 0.26  [25664/48000]
# Train loss 100th: 0.24  [32064/48000]
# Train loss 100th: 0.18  [38464/48000]
# Train loss 100th: 0.21  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.0%, Precision: 0.9222, Recall: 0.9195, F1-score: 0.9198, Avg loss: 0.214376
#
# Time 60.34
# Epoch 1
# -------------------------------
# Train loss 100th: 0.69  [   64/48000]
# Train loss 100th: 0.42  [ 6464/48000]
# Train loss 100th: 0.37  [12864/48000]
# Train loss 100th: 0.28  [19264/48000]
# Train loss 100th: 0.28  [25664/48000]
# Train loss 100th: 0.41  [32064/48000]
# Train loss 100th: 0.18  [38464/48000]
# Train loss 100th: 0.24  [44864/48000]
# Avg Train Loss: 0.31
# Test Metrics:
#  Accuracy: 91.0%, Precision: 0.9145, Recall: 0.9098, F1-score: 0.9102, Avg loss: 0.231293
#
# Time 3.05
# Epoch 2
# -------------------------------
# Train loss 100th: 0.37  [   64/48000]
# Train loss 100th: 0.38  [ 6464/48000]
# Train loss 100th: 0.18  [12864/48000]
# Train loss 100th: 0.23  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.17  [32064/48000]
# Train loss 100th: 0.22  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 91.8%, Precision: 0.9193, Recall: 0.9176, F1-score: 0.9179, Avg loss: 0.211228
#
# Time 6.13
# Epoch 3
# -------------------------------
# Train loss 100th: 0.32  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.23  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.22  [32064/48000]
# Train loss 100th: 0.15  [38464/48000]
# Train loss 100th: 0.26  [44864/48000]
# Avg Train Loss: 0.21
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9279, Recall: 0.9267, F1-score: 0.9269, Avg loss: 0.197240
#
# Time 9.18
# Epoch 4
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.15  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.25  [25664/48000]
# Train loss 100th: 0.32  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.21  [44864/48000]
# Avg Train Loss: 0.20
# Test Metrics:
#  Accuracy: 92.2%, Precision: 0.9258, Recall: 0.9218, F1-score: 0.9222, Avg loss: 0.200049
#
# Time 12.22
# Epoch 5
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.21  [12864/48000]
# Train loss 100th: 0.35  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.16  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.19
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9279, Recall: 0.9272, F1-score: 0.9274, Avg loss: 0.193115
#
# Time 15.31
# Epoch 6
# -------------------------------
# Train loss 100th: 0.18  [   64/48000]
# Train loss 100th: 0.23  [ 6464/48000]
# Train loss 100th: 0.15  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.16  [38464/48000]
# Train loss 100th: 0.22  [44864/48000]
# Avg Train Loss: 0.18
# Test Metrics:
#  Accuracy: 93.1%, Precision: 0.9308, Recall: 0.9309, F1-score: 0.9308, Avg loss: 0.186043
#
# Time 18.38
# Epoch 7
# -------------------------------
# Train loss 100th: 0.21  [   64/48000]
# Train loss 100th: 0.23  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.25  [25664/48000]
# Train loss 100th: 0.16  [32064/48000]
# Train loss 100th: 0.20  [38464/48000]
# Train loss 100th: 0.19  [44864/48000]
# Avg Train Loss: 0.17
# Test Metrics:
#  Accuracy: 93.1%, Precision: 0.9308, Recall: 0.9304, F1-score: 0.9305, Avg loss: 0.183504
#
# Time 21.54
# Epoch 8
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.13  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.18  [25664/48000]
# Train loss 100th: 0.12  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.35  [44864/48000]
# Avg Train Loss: 0.17
# Test Metrics:
#  Accuracy: 93.2%, Precision: 0.9315, Recall: 0.9316, F1-score: 0.9315, Avg loss: 0.179501
#
# Time 24.63
# Epoch 9
# -------------------------------
# Train loss 100th: 0.12  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.18  [12864/48000]
# Train loss 100th: 0.26  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.13  [32064/48000]
# Train loss 100th: 0.21  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9383, Recall: 0.9374, F1-score: 0.9376, Avg loss: 0.170338
#
# Time 27.69
# Epoch 10
# -------------------------------
# Train loss 100th: 0.19  [   64/48000]
# Train loss 100th: 0.20  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.18  [32064/48000]
# Train loss 100th: 0.07  [38464/48000]
# Train loss 100th: 0.16  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 94.0%, Precision: 0.9417, Recall: 0.9399, F1-score: 0.9402, Avg loss: 0.164334
#
# Time 30.77
# Epoch 11
# -------------------------------
# Train loss 100th: 0.26  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.10  [19264/48000]
# Train loss 100th: 0.12  [25664/48000]
# Train loss 100th: 0.19  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 94.2%, Precision: 0.9436, Recall: 0.9421, F1-score: 0.9423, Avg loss: 0.160358
#
# Time 33.82
# Epoch 12
# -------------------------------
# Train loss 100th: 0.18  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.16  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 94.4%, Precision: 0.9441, Recall: 0.9436, F1-score: 0.9437, Avg loss: 0.153840
#
# Time 36.9
# Epoch 13
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.04  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.13  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9460, Recall: 0.9457, F1-score: 0.9458, Avg loss: 0.148647
#
# Time 39.92
# Epoch 14
# -------------------------------
# Train loss 100th: 0.19  [   64/48000]
# Train loss 100th: 0.13  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.05  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.09  [38464/48000]
# Train loss 100th: 0.05  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.4%, Precision: 0.9441, Recall: 0.9440, F1-score: 0.9441, Avg loss: 0.154223
#
# Time 42.94
# Epoch 15
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.24  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9454, Recall: 0.9455, F1-score: 0.9454, Avg loss: 0.151500
#
# Time 46.03
# Epoch 16
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.03  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.13  [19264/48000]
# Train loss 100th: 0.16  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.10  [38464/48000]
# Train loss 100th: 0.06  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.8%, Precision: 0.9481, Recall: 0.9477, F1-score: 0.9478, Avg loss: 0.148429
#
# Time 49.14
# Epoch 17
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.05  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9453, Recall: 0.9444, F1-score: 0.9446, Avg loss: 0.157330
#
# Time 52.31
# Epoch 18
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.02  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.13  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.22  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9462, Recall: 0.9462, F1-score: 0.9462, Avg loss: 0.149503
#
# Time 55.37
# Epoch 19
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.14  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.05  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9469, Recall: 0.9465, F1-score: 0.9466, Avg loss: 0.146904
#
# Time 58.43
# Epoch 20
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.04  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.13  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9462, Recall: 0.9444, F1-score: 0.9447, Avg loss: 0.159356
#
# Time 61.47
# Epoch 1
# -------------------------------
# Train loss 100th: 0.70  [   64/48000]
# Train loss 100th: 0.29  [ 6464/48000]
# Train loss 100th: 0.40  [12864/48000]
# Train loss 100th: 0.31  [19264/48000]
# Train loss 100th: 0.30  [25664/48000]
# Train loss 100th: 0.35  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.23  [44864/48000]
# Avg Train Loss: 0.33
# Test Metrics:
#  Accuracy: 91.0%, Precision: 0.9103, Recall: 0.9104, F1-score: 0.9102, Avg loss: 0.226276
#
# Time 3.07
# Epoch 2
# -------------------------------
# Train loss 100th: 0.24  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.30  [12864/48000]
# Train loss 100th: 0.17  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.24  [32064/48000]
# Train loss 100th: 0.31  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 92.2%, Precision: 0.9216, Recall: 0.9216, F1-score: 0.9216, Avg loss: 0.202991
#
# Time 6.07
# Epoch 3
# -------------------------------
# Train loss 100th: 0.16  [   64/48000]
# Train loss 100th: 0.20  [ 6464/48000]
# Train loss 100th: 0.20  [12864/48000]
# Train loss 100th: 0.39  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.22  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.20
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9278, Recall: 0.9266, F1-score: 0.9268, Avg loss: 0.191309
#
# Time 9.08
# Epoch 4
# -------------------------------
# Train loss 100th: 0.17  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.27  [19264/48000]
# Train loss 100th: 0.25  [25664/48000]
# Train loss 100th: 0.21  [32064/48000]
# Train loss 100th: 0.13  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.18
# Test Metrics:
#  Accuracy: 93.2%, Precision: 0.9324, Recall: 0.9324, F1-score: 0.9324, Avg loss: 0.187950
#
# Time 12.09
# Epoch 5
# -------------------------------
# Train loss 100th: 0.22  [   64/48000]
# Train loss 100th: 0.14  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.21  [44864/48000]
# Avg Train Loss: 0.17
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9337, Recall: 0.9330, F1-score: 0.9332, Avg loss: 0.185409
#
# Time 15.17
# Epoch 6
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.28  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9276, Recall: 0.9276, F1-score: 0.9276, Avg loss: 0.188224
#
# Time 18.22
# Epoch 7
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.18  [12864/48000]
# Train loss 100th: 0.13  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.17  [32064/48000]
# Train loss 100th: 0.24  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.14
# Test Metrics:
#  Accuracy: 93.0%, Precision: 0.9301, Recall: 0.9302, F1-score: 0.9302, Avg loss: 0.192128
#
# Time 21.35
# Epoch 8
# -------------------------------
# Train loss 100th: 0.10  [   64/48000]
# Train loss 100th: 0.24  [ 6464/48000]
# Train loss 100th: 0.05  [12864/48000]
# Train loss 100th: 0.29  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9334, Recall: 0.9328, F1-score: 0.9329, Avg loss: 0.183353
#
# Time 24.46
# Epoch 9
# -------------------------------
# Train loss 100th: 0.05  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.21  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 93.5%, Precision: 0.9348, Recall: 0.9346, F1-score: 0.9346, Avg loss: 0.192291
#
# Time 27.53
# Epoch 10
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.08  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.03  [38464/48000]
# Train loss 100th: 0.22  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 93.2%, Precision: 0.9322, Recall: 0.9321, F1-score: 0.9318, Avg loss: 0.194279
#
# Time 30.6
# Epoch 11
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.02  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.13  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9379, Recall: 0.9378, F1-score: 0.9378, Avg loss: 0.187822
#
# Time 33.66
# Epoch 12
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.08  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.10  [38464/48000]
# Train loss 100th: 0.03  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 94.0%, Precision: 0.9401, Recall: 0.9393, F1-score: 0.9394, Avg loss: 0.182955
#
# Time 36.72
# Epoch 13
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.19  [12864/48000]
# Train loss 100th: 0.10  [19264/48000]
# Train loss 100th: 0.09  [25664/48000]
# Train loss 100th: 0.05  [32064/48000]
# Train loss 100th: 0.03  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 93.9%, Precision: 0.9398, Recall: 0.9385, F1-score: 0.9388, Avg loss: 0.193756
#
# Time 39.74
# Epoch 14
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.05  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.17  [32064/48000]
# Train loss 100th: 0.02  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 94.1%, Precision: 0.9420, Recall: 0.9412, F1-score: 0.9414, Avg loss: 0.182976
#
# Time 42.81
# Epoch 15
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.01  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.04  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.15  [32064/48000]
# Train loss 100th: 0.02  [38464/48000]
# Train loss 100th: 0.02  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9384, Recall: 0.9383, F1-score: 0.9383, Avg loss: 0.191818
#
# Time 45.89
# Epoch 16
# -------------------------------
# Train loss 100th: 0.05  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.13  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 93.7%, Precision: 0.9373, Recall: 0.9374, F1-score: 0.9373, Avg loss: 0.199081
#
# Time 48.95
# Epoch 17
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.27  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.04  [32064/48000]
# Train loss 100th: 0.07  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 94.3%, Precision: 0.9436, Recall: 0.9426, F1-score: 0.9429, Avg loss: 0.197283
#
# Time 51.99
# Epoch 18
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.05  [12864/48000]
# Train loss 100th: 0.10  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.05  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 94.0%, Precision: 0.9396, Recall: 0.9395, F1-score: 0.9396, Avg loss: 0.192043
#
# Time 55.2
# Epoch 19
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.02  [ 6464/48000]
# Train loss 100th: 0.03  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.03  [25664/48000]
# Train loss 100th: 0.04  [32064/48000]
# Train loss 100th: 0.02  [38464/48000]
# Train loss 100th: 0.05  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 94.1%, Precision: 0.9411, Recall: 0.9410, F1-score: 0.9411, Avg loss: 0.190706
#
# Time 58.23
# Epoch 20
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.01  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.02  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.04  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 94.4%, Precision: 0.9447, Recall: 0.9442, F1-score: 0.9443, Avg loss: 0.192285
#
# Time 61.26
# Epoch 1
# -------------------------------
# Train loss 100th: 0.71  [   64/48000]
# Train loss 100th: 0.37  [ 6464/48000]
# Train loss 100th: 0.43  [12864/48000]
# Train loss 100th: 0.28  [19264/48000]
# Train loss 100th: 0.28  [25664/48000]
# Train loss 100th: 0.26  [32064/48000]
# Train loss 100th: 0.27  [38464/48000]
# Train loss 100th: 0.38  [44864/48000]
# Avg Train Loss: 0.32
# Test Metrics:
#  Accuracy: 91.5%, Precision: 0.9150, Recall: 0.9147, F1-score: 0.9148, Avg loss: 0.220485
#
# Time 3.07
# Epoch 2
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.21  [ 6464/48000]
# Train loss 100th: 0.30  [12864/48000]
# Train loss 100th: 0.27  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.25  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.6%, Precision: 0.9277, Recall: 0.9255, F1-score: 0.9258, Avg loss: 0.201199
#
# Time 6.12
# Epoch 3
# -------------------------------
# Train loss 100th: 0.24  [   64/48000]
# Train loss 100th: 0.21  [ 6464/48000]
# Train loss 100th: 0.15  [12864/48000]
# Train loss 100th: 0.29  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.11  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.20
# Test Metrics:
#  Accuracy: 92.9%, Precision: 0.9296, Recall: 0.9289, F1-score: 0.9290, Avg loss: 0.191121
#
# Time 9.16
# Epoch 4
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.17  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.06  [25664/48000]
# Train loss 100th: 0.35  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.18
# Test Metrics:
#  Accuracy: 93.2%, Precision: 0.9326, Recall: 0.9313, F1-score: 0.9316, Avg loss: 0.184619
#
# Time 12.23
# Epoch 5
# -------------------------------
# Train loss 100th: 0.23  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.18  [12864/48000]
# Train loss 100th: 0.21  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.16  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.19  [44864/48000]
# Avg Train Loss: 0.16
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9326, Recall: 0.9325, F1-score: 0.9326, Avg loss: 0.178171
#
# Time 15.29
# Epoch 6
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.24  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.11  [44864/48000]
# Avg Train Loss: 0.14
# Test Metrics:
#  Accuracy: 93.5%, Precision: 0.9354, Recall: 0.9350, F1-score: 0.9351, Avg loss: 0.172145
#
# Time 18.32
# Epoch 7
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.12  [25664/48000]
# Train loss 100th: 0.13  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 93.5%, Precision: 0.9353, Recall: 0.9354, F1-score: 0.9353, Avg loss: 0.175702
#
# Time 21.4
# Epoch 8
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.24  [19264/48000]
# Train loss 100th: 0.06  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.07  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.2%, Precision: 0.9423, Recall: 0.9415, F1-score: 0.9417, Avg loss: 0.173482
#
# Time 24.53
# Epoch 9
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.08  [19264/48000]
# Train loss 100th: 0.18  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 94.1%, Precision: 0.9413, Recall: 0.9404, F1-score: 0.9406, Avg loss: 0.180586
#
# Time 27.62
# Epoch 10
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.22  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.19  [25664/48000]
# Train loss 100th: 0.11  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.11  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 94.2%, Precision: 0.9421, Recall: 0.9419, F1-score: 0.9420, Avg loss: 0.185645
#
# Time 30.68
# Epoch 11
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.06  [25664/48000]
# Train loss 100th: 0.04  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.02  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 94.1%, Precision: 0.9418, Recall: 0.9412, F1-score: 0.9414, Avg loss: 0.187206
#
# Time 33.74
# Epoch 12
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.06  [12864/48000]
# Train loss 100th: 0.05  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.10  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 94.1%, Precision: 0.9409, Recall: 0.9409, F1-score: 0.9409, Avg loss: 0.191546
#
# Time 36.84
# Epoch 13
# -------------------------------
# Train loss 100th: 0.10  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.09  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.08  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9462, Recall: 0.9459, F1-score: 0.9460, Avg loss: 0.173888
#
# Time 39.86
# Epoch 14
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.01  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9453, Recall: 0.9454, F1-score: 0.9453, Avg loss: 0.199928
#
# Time 42.94
# Epoch 15
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.04  [12864/48000]
# Train loss 100th: 0.01  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.02  [38464/48000]
# Train loss 100th: 0.04  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 94.8%, Precision: 0.9483, Recall: 0.9476, F1-score: 0.9478, Avg loss: 0.189321
#
# Time 45.99
# Epoch 16
# -------------------------------
# Train loss 100th: 0.01  [   64/48000]
# Train loss 100th: 0.04  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.02  [25664/48000]
# Train loss 100th: 0.05  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.03  [44864/48000]
# Avg Train Loss: 0.05
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9469, Recall: 0.9464, F1-score: 0.9465, Avg loss: 0.210389
#
# Time 49.03
# Epoch 17
# -------------------------------
# Train loss 100th: 0.01  [   64/48000]
# Train loss 100th: 0.01  [ 6464/48000]
# Train loss 100th: 0.01  [12864/48000]
# Train loss 100th: 0.05  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.07  [44864/48000]
# Avg Train Loss: 0.05
# Test Metrics:
#  Accuracy: 94.3%, Precision: 0.9434, Recall: 0.9435, F1-score: 0.9434, Avg loss: 0.223349
#
# Time 52.13
# Epoch 18
# -------------------------------
# Train loss 100th: 0.00  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.01  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.02  [25664/48000]
# Train loss 100th: 0.04  [32064/48000]
# Train loss 100th: 0.02  [38464/48000]
# Train loss 100th: 0.01  [44864/48000]
# Avg Train Loss: 0.05
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9461, Recall: 0.9459, F1-score: 0.9460, Avg loss: 0.205218
#
# Time 55.3
# Epoch 19
# -------------------------------
# Train loss 100th: 0.05  [   64/48000]
# Train loss 100th: 0.01  [ 6464/48000]
# Train loss 100th: 0.04  [12864/48000]
# Train loss 100th: 0.05  [19264/48000]
# Train loss 100th: 0.01  [25664/48000]
# Train loss 100th: 0.02  [32064/48000]
# Train loss 100th: 0.01  [38464/48000]
# Train loss 100th: 0.04  [44864/48000]
# Avg Train Loss: 0.04
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9475, Recall: 0.9462, F1-score: 0.9464, Avg loss: 0.230939
#
# Time 58.36
# Epoch 20
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.06  [44864/48000]
# Avg Train Loss: 0.04
# Test Metrics:
#  Accuracy: 94.8%, Precision: 0.9482, Recall: 0.9477, F1-score: 0.9479, Avg loss: 0.211300
#
# Time 61.41
# Epoch 1
# -------------------------------
# Train loss 100th: 0.69  [   64/48000]
# Train loss 100th: 0.25  [ 6464/48000]
# Train loss 100th: 0.29  [12864/48000]
# Train loss 100th: 0.58  [19264/48000]
# Train loss 100th: 0.25  [25664/48000]
# Train loss 100th: 0.32  [32064/48000]
# Train loss 100th: 0.22  [38464/48000]
# Train loss 100th: 0.20  [44864/48000]
# Avg Train Loss: 0.33
# Test Metrics:
#  Accuracy: 91.2%, Precision: 0.9134, Recall: 0.9115, F1-score: 0.9118, Avg loss: 0.225919
#
# Time 3.01
# Epoch 2
# -------------------------------
# Train loss 100th: 0.38  [   64/48000]
# Train loss 100th: 0.23  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.23  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.17  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.23  [44864/48000]
# Avg Train Loss: 0.23
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9279, Recall: 0.9268, F1-score: 0.9270, Avg loss: 0.194357
#
# Time 6.04
# Epoch 3
# -------------------------------
# Train loss 100th: 0.10  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.24  [12864/48000]
# Train loss 100th: 0.15  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.13  [32064/48000]
# Train loss 100th: 0.25  [38464/48000]
# Train loss 100th: 0.20  [44864/48000]
# Avg Train Loss: 0.20
# Test Metrics:
#  Accuracy: 92.1%, Precision: 0.9218, Recall: 0.9213, F1-score: 0.9209, Avg loss: 0.206630
#
# Time 9.08
# Epoch 4
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.29  [32064/48000]
# Train loss 100th: 0.20  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.18
# Test Metrics:
#  Accuracy: 93.1%, Precision: 0.9314, Recall: 0.9306, F1-score: 0.9308, Avg loss: 0.183738
#
# Time 12.09
# Epoch 5
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.21  [19264/48000]
# Train loss 100th: 0.21  [25664/48000]
# Train loss 100th: 0.21  [32064/48000]
# Train loss 100th: 0.15  [38464/48000]
# Train loss 100th: 0.07  [44864/48000]
# Avg Train Loss: 0.16
# Test Metrics:
#  Accuracy: 92.9%, Precision: 0.9291, Recall: 0.9291, F1-score: 0.9291, Avg loss: 0.186687
#
# Time 15.18
# Epoch 6
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.16  [ 6464/48000]
# Train loss 100th: 0.22  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.24  [25664/48000]
# Train loss 100th: 0.19  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 93.2%, Precision: 0.9328, Recall: 0.9315, F1-score: 0.9317, Avg loss: 0.184969
#
# Time 18.24
# Epoch 7
# -------------------------------
# Train loss 100th: 0.14  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.15  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.08  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9338, Recall: 0.9330, F1-score: 0.9332, Avg loss: 0.198363
#
# Time 21.31
# Epoch 8
# -------------------------------
# Train loss 100th: 0.11  [   64/48000]
# Train loss 100th: 0.27  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.11  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9331, Recall: 0.9331, F1-score: 0.9331, Avg loss: 0.193050
#
# Time 24.52
# Epoch 9
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.14  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.06  [32064/48000]
# Train loss 100th: 0.09  [38464/48000]
# Train loss 100th: 0.10  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 93.3%, Precision: 0.9331, Recall: 0.9329, F1-score: 0.9330, Avg loss: 0.198970
#
# Time 27.56
# Epoch 10
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 93.7%, Precision: 0.9367, Recall: 0.9368, F1-score: 0.9367, Avg loss: 0.194935
#
# Time 30.61
# Epoch 11
# -------------------------------
# Train loss 100th: 0.05  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.04  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.26  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.17  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 93.4%, Precision: 0.9350, Recall: 0.9335, F1-score: 0.9337, Avg loss: 0.223938
#
# Time 33.64
# Epoch 12
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.11  [19264/48000]
# Train loss 100th: 0.09  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9382, Recall: 0.9381, F1-score: 0.9381, Avg loss: 0.210190
#
# Time 36.67
# Epoch 13
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.03  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.03  [25664/48000]
# Train loss 100th: 0.14  [32064/48000]
# Train loss 100th: 0.08  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 93.7%, Precision: 0.9369, Recall: 0.9366, F1-score: 0.9367, Avg loss: 0.226136
#
# Time 39.74
# Epoch 14
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.08  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.01  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.04  [38464/48000]
# Train loss 100th: 0.04  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 93.6%, Precision: 0.9361, Recall: 0.9361, F1-score: 0.9361, Avg loss: 0.233916
#
# Time 42.78
# Epoch 15
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.07
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9386, Recall: 0.9378, F1-score: 0.9379, Avg loss: 0.230682
#
# Time 45.79
# Epoch 16
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.04  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.09  [25664/48000]
# Train loss 100th: 0.05  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 93.9%, Precision: 0.9392, Recall: 0.9391, F1-score: 0.9391, Avg loss: 0.226358
#
# Time 48.79
# Epoch 17
# -------------------------------
# Train loss 100th: 0.01  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.00  [38464/48000]
# Train loss 100th: 0.06  [44864/48000]
# Avg Train Loss: 0.06
# Test Metrics:
#  Accuracy: 93.8%, Precision: 0.9378, Recall: 0.9378, F1-score: 0.9378, Avg loss: 0.222860
#
# Time 51.86
# Epoch 18
# -------------------------------
# Train loss 100th: 0.21  [   64/48000]
# Train loss 100th: 0.03  [ 6464/48000]
# Train loss 100th: 0.02  [12864/48000]
# Train loss 100th: 0.04  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.03  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.05
# Test Metrics:
#  Accuracy: 93.5%, Precision: 0.9351, Recall: 0.9352, F1-score: 0.9352, Avg loss: 0.242640
#
# Time 54.96
# Epoch 19
# -------------------------------
# Train loss 100th: 0.02  [   64/48000]
# Train loss 100th: 0.15  [ 6464/48000]
# Train loss 100th: 0.03  [12864/48000]
# Train loss 100th: 0.02  [19264/48000]
# Train loss 100th: 0.01  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.10  [38464/48000]
# Train loss 100th: 0.05  [44864/48000]
# Avg Train Loss: 0.05
# Test Metrics:
#  Accuracy: 93.6%, Precision: 0.9362, Recall: 0.9361, F1-score: 0.9361, Avg loss: 0.260290
#
# Time 57.99
# Epoch 20
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.04  [ 6464/48000]
# ...
#
# Time 21.26
# Epoch 8
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.15  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.24  [19264/48000]
# Train loss 100th: 0.16  [25664/48000]
# Train loss 100th: 0.26  [32064/48000]
# Train loss 100th: 0.13  [38464/48000]
# Train loss 100th: 0.20  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9481, Recall: 0.9465, F1-score: 0.9468, Avg loss: 0.157892
#
# Time 24.29
# Epoch 9
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.11  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.20  [32064/48000]
# Train loss 100th: 0.16  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.14
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9480, Recall: 0.9465, F1-score: 0.9468, Avg loss: 0.165789
#
# Time 27.4
# Epoch 10
# -------------------------------
# Train loss 100th: 0.22  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.05  [12864/48000]
# Train loss 100th: 0.04  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.07  [38464/48000]
# Train loss 100th: 0.14  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9452, Recall: 0.9448, F1-score: 0.9449, Avg loss: 0.153473
#
# Time 30.45
# Epoch 11
# -------------------------------
# Train loss 100th: 0.16  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.16  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.08  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9469, Recall: 0.9456, F1-score: 0.9458, Avg loss: 0.155744
#
# Time 33.46
# Epoch 12
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.04  [ 6464/48000]
# Train loss 100th: 0.32  [12864/48000]
# Train loss 100th: 0.04  [19264/48000]
# Train loss 100th: 0.07  [25664/48000]
# Train loss 100th: 0.15  [32064/48000]
# Train loss 100th: 0.06  [38464/48000]
# Train loss 100th: 0.14  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 94.8%, Precision: 0.9488, Recall: 0.9474, F1-score: 0.9477, Avg loss: 0.180368
#
# Time 36.51
# Epoch 13
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.06  [12864/48000]
# Train loss 100th: 0.12  [19264/48000]
# Train loss 100th: 0.13  [25664/48000]
# Train loss 100th: 0.22  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.05  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 93.7%, Precision: 0.9372, Recall: 0.9370, F1-score: 0.9367, Avg loss: 0.191323
#
# Time 39.52
# Epoch 14
# -------------------------------
# Train loss 100th: 0.09  [   64/48000]
# Train loss 100th: 0.12  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.16  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.19  [32064/48000]
# Train loss 100th: 0.18  [38464/48000]
# Train loss 100th: 0.19  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9462, Recall: 0.9449, F1-score: 0.9452, Avg loss: 0.173869
#
# Time 42.57
# Epoch 15
# -------------------------------
# Train loss 100th: 0.12  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.03  [12864/48000]
# Train loss 100th: 0.07  [19264/48000]
# Train loss 100th: 0.08  [25664/48000]
# Train loss 100th: 0.09  [32064/48000]
# Train loss 100th: 0.07  [38464/48000]
# Train loss 100th: 0.05  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 94.7%, Precision: 0.9476, Recall: 0.9473, F1-score: 0.9474, Avg loss: 0.184587
#
# Time 45.58
# Epoch 16
# -------------------------------
# Train loss 100th: 0.19  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.10  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.12  [32064/48000]
# Train loss 100th: 0.21  [38464/48000]
# Train loss 100th: 0.07  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 94.3%, Precision: 0.9428, Recall: 0.9427, F1-score: 0.9427, Avg loss: 0.189406
#
# Time 48.58
# Epoch 17
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.04  [ 6464/48000]
# Train loss 100th: 0.04  [12864/48000]
# Train loss 100th: 0.10  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.06  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 94.5%, Precision: 0.9449, Recall: 0.9448, F1-score: 0.9448, Avg loss: 0.173251
#
# Time 51.56
# Epoch 18
# -------------------------------
# Train loss 100th: 0.04  [   64/48000]
# Train loss 100th: 0.14  [ 6464/48000]
# Train loss 100th: 0.08  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.05  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.05  [38464/48000]
# Train loss 100th: 0.06  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9467, Recall: 0.9460, F1-score: 0.9462, Avg loss: 0.191293
#
# Time 54.54
# Epoch 19
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.09  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.03  [32064/48000]
# Train loss 100th: 0.10  [38464/48000]
# Train loss 100th: 0.07  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9478, Recall: 0.9458, F1-score: 0.9462, Avg loss: 0.189080
#
# Time 57.58
# Epoch 20
# -------------------------------
# Train loss 100th: 0.13  [   64/48000]
# Train loss 100th: 0.11  [ 6464/48000]
# Train loss 100th: 0.01  [12864/48000]
# Train loss 100th: 0.03  [19264/48000]
# Train loss 100th: 0.01  [25664/48000]
# Train loss 100th: 0.10  [32064/48000]
# Train loss 100th: 0.03  [38464/48000]
# Train loss 100th: 0.19  [44864/48000]
# Avg Train Loss: 0.08
# Test Metrics:
#  Accuracy: 94.6%, Precision: 0.9461, Recall: 0.9454, F1-score: 0.9455, Avg loss: 0.187226
#
# Time 60.64
# Epoch 1
# -------------------------------
# Train loss 100th: 0.71  [   64/48000]
# Train loss 100th: 0.52  [ 6464/48000]
# Train loss 100th: 0.46  [12864/48000]
# Train loss 100th: 0.50  [19264/48000]
# Train loss 100th: 0.54  [25664/48000]
# Train loss 100th: 0.38  [32064/48000]
# Train loss 100th: 0.30  [38464/48000]
# Train loss 100th: 0.32  [44864/48000]
# Avg Train Loss: 0.44
# Test Metrics:
#  Accuracy: 87.5%, Precision: 0.8815, Recall: 0.8744, F1-score: 0.8746, Avg loss: 0.318342
#
# Time 3.03
# Epoch 2
# -------------------------------
# Train loss 100th: 0.30  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.32  [12864/48000]
# Train loss 100th: 0.45  [19264/48000]
# Train loss 100th: 0.40  [25664/48000]
# Train loss 100th: 0.58  [32064/48000]
# Train loss 100th: 0.43  [38464/48000]
# Train loss 100th: 0.26  [44864/48000]
# Avg Train Loss: 0.32
# Test Metrics:
#  Accuracy: 89.6%, Precision: 0.8977, Recall: 0.8958, F1-score: 0.8961, Avg loss: 0.267350
#
# Time 6.06
# Epoch 3
# -------------------------------
# Train loss 100th: 0.31  [   64/48000]
# Train loss 100th: 0.25  [ 6464/48000]
# Train loss 100th: 0.37  [12864/48000]
# Train loss 100th: 0.27  [19264/48000]
# Train loss 100th: 0.22  [25664/48000]
# Train loss 100th: 0.33  [32064/48000]
# Train loss 100th: 0.24  [38464/48000]
# Train loss 100th: 0.40  [44864/48000]
# Avg Train Loss: 0.27
# Test Metrics:
#  Accuracy: 90.6%, Precision: 0.9073, Recall: 0.9053, F1-score: 0.9056, Avg loss: 0.244299
#
# Time 9.07
# Epoch 4
# -------------------------------
# Train loss 100th: 0.27  [   64/48000]
# Train loss 100th: 0.21  [ 6464/48000]
# Train loss 100th: 0.16  [12864/48000]
# Train loss 100th: 0.24  [19264/48000]
# Train loss 100th: 0.33  [25664/48000]
# Train loss 100th: 0.27  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.26  [44864/48000]
# Avg Train Loss: 0.24
# Test Metrics:
#  Accuracy: 91.3%, Precision: 0.9138, Recall: 0.9132, F1-score: 0.9134, Avg loss: 0.225987
#
# Time 12.08
# Epoch 5
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.30  [ 6464/48000]
# Train loss 100th: 0.26  [12864/48000]
# Train loss 100th: 0.30  [19264/48000]
# Train loss 100th: 0.42  [25664/48000]
# Train loss 100th: 0.24  [32064/48000]
# Train loss 100th: 0.23  [38464/48000]
# Train loss 100th: 0.31  [44864/48000]
# Avg Train Loss: 0.22
# Test Metrics:
#  Accuracy: 91.7%, Precision: 0.9169, Recall: 0.9167, F1-score: 0.9168, Avg loss: 0.215662
#
# Time 15.13
# Epoch 6
# -------------------------------
# Train loss 100th: 0.25  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.21  [12864/48000]
# Train loss 100th: 0.21  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.19  [32064/48000]
# Train loss 100th: 0.16  [38464/48000]
# Train loss 100th: 0.23  [44864/48000]
# Avg Train Loss: 0.21
# Test Metrics:
#  Accuracy: 92.0%, Precision: 0.9202, Recall: 0.9200, F1-score: 0.9200, Avg loss: 0.205980
#
# Time 18.12
# Epoch 7
# -------------------------------
# Train loss 100th: 0.10  [   64/48000]
# Train loss 100th: 0.17  [ 6464/48000]
# Train loss 100th: 0.21  [12864/48000]
# Train loss 100th: 0.22  [19264/48000]
# Train loss 100th: 0.29  [25664/48000]
# Train loss 100th: 0.22  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.16  [44864/48000]
# Avg Train Loss: 0.19
# Test Metrics:
#  Accuracy: 92.5%, Precision: 0.9253, Recall: 0.9243, F1-score: 0.9245, Avg loss: 0.201175
#
# Time 21.17
# Epoch 8
# -------------------------------
# Train loss 100th: 0.15  [   64/48000]
# Train loss 100th: 0.18  [ 6464/48000]
# Train loss 100th: 0.30  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.15  [25664/48000]
# Train loss 100th: 0.16  [32064/48000]
# Train loss 100th: 0.13  [38464/48000]
# Train loss 100th: 0.22  [44864/48000]
# Avg Train Loss: 0.18
# Test Metrics:
#  Accuracy: 92.3%, Precision: 0.9243, Recall: 0.9230, F1-score: 0.9232, Avg loss: 0.199057
#
# Time 24.17
# Epoch 9
# -------------------------------
# Train loss 100th: 0.20  [   64/48000]
# Train loss 100th: 0.22  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.21  [25664/48000]
# Train loss 100th: 0.23  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.12  [44864/48000]
# Avg Train Loss: 0.17
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9279, Recall: 0.9272, F1-score: 0.9274, Avg loss: 0.194062
#
# Time 27.19
# Epoch 10
# -------------------------------
# Train loss 100th: 0.12  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.17  [19264/48000]
# Train loss 100th: 0.17  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.18  [38464/48000]
# Train loss 100th: 0.08  [44864/48000]
# Avg Train Loss: 0.16
# Test Metrics:
#  Accuracy: 92.7%, Precision: 0.9284, Recall: 0.9270, F1-score: 0.9272, Avg loss: 0.195950
#
# Time 30.29
# Epoch 11
# -------------------------------
# Train loss 100th: 0.26  [   64/48000]
# Train loss 100th: 0.15  [ 6464/48000]
# Train loss 100th: 0.14  [12864/48000]
# Train loss 100th: 0.14  [19264/48000]
# Train loss 100th: 0.21  [25664/48000]
# Train loss 100th: 0.39  [32064/48000]
# Train loss 100th: 0.20  [38464/48000]
# Train loss 100th: 0.13  [44864/48000]
# Avg Train Loss: 0.15
# Test Metrics:
#  Accuracy: 92.9%, Precision: 0.9290, Recall: 0.9287, F1-score: 0.9288, Avg loss: 0.192618
#
# Time 33.31
# Epoch 12
# -------------------------------
# Train loss 100th: 0.18  [   64/48000]
# Train loss 100th: 0.19  [ 6464/48000]
# Train loss 100th: 0.26  [12864/48000]
# Train loss 100th: 0.08  [19264/48000]
# Train loss 100th: 0.14  [25664/48000]
# Train loss 100th: 0.12  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.18  [44864/48000]
# Avg Train Loss: 0.14
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9283, Recall: 0.9276, F1-score: 0.9278, Avg loss: 0.191515
#
# Time 36.36
# Epoch 13
# -------------------------------
# Train loss 100th: 0.06  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.20  [19264/48000]
# Train loss 100th: 0.11  [25664/48000]
# Train loss 100th: 0.18  [32064/48000]
# Train loss 100th: 0.19  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9279, Recall: 0.9273, F1-score: 0.9274, Avg loss: 0.195903
#
# Time 39.4
# Epoch 14
# -------------------------------
# Train loss 100th: 0.13  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.20  [12864/48000]
# Train loss 100th: 0.13  [19264/48000]
# Train loss 100th: 0.20  [25664/48000]
# Train loss 100th: 0.09  [32064/48000]
# Train loss 100th: 0.14  [38464/48000]
# Train loss 100th: 0.11  [44864/48000]
# Avg Train Loss: 0.13
# Test Metrics:
#  Accuracy: 93.0%, Precision: 0.9301, Recall: 0.9298, F1-score: 0.9299, Avg loss: 0.193091
#
# Time 42.41
# Epoch 15
# -------------------------------
# Train loss 100th: 0.17  [   64/48000]
# Train loss 100th: 0.10  [ 6464/48000]
# Train loss 100th: 0.03  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.04  [25664/48000]
# Train loss 100th: 0.16  [32064/48000]
# Train loss 100th: 0.27  [38464/48000]
# Train loss 100th: 0.08  [44864/48000]
# Avg Train Loss: 0.12
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9283, Recall: 0.9277, F1-score: 0.9279, Avg loss: 0.194732
#
# Time 45.47
# Epoch 16
# -------------------------------
# Train loss 100th: 0.03  [   64/48000]
# Train loss 100th: 0.09  [ 6464/48000]
# Train loss 100th: 0.07  [12864/48000]
# Train loss 100th: 0.26  [19264/48000]
# Train loss 100th: 0.18  [25664/48000]
# Train loss 100th: 0.08  [32064/48000]
# Train loss 100th: 0.11  [38464/48000]
# Train loss 100th: 0.14  [44864/48000]
# Avg Train Loss: 0.11
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9284, Recall: 0.9284, F1-score: 0.9284, Avg loss: 0.200958
#
# Time 48.49
# Epoch 17
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.05  [ 6464/48000]
# Train loss 100th: 0.12  [12864/48000]
# Train loss 100th: 0.06  [19264/48000]
# Train loss 100th: 0.10  [25664/48000]
# Train loss 100th: 0.15  [32064/48000]
# Train loss 100th: 0.09  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9277, Recall: 0.9276, F1-score: 0.9276, Avg loss: 0.202762
#
# Time 51.5
# Epoch 18
# -------------------------------
# Train loss 100th: 0.07  [   64/48000]
# Train loss 100th: 0.06  [ 6464/48000]
# Train loss 100th: 0.09  [12864/48000]
# Train loss 100th: 0.24  [19264/48000]
# Train loss 100th: 0.06  [25664/48000]
# Train loss 100th: 0.02  [32064/48000]
# Train loss 100th: 0.17  [38464/48000]
# Train loss 100th: 0.11  [44864/48000]
# Avg Train Loss: 0.10
# Test Metrics:
#  Accuracy: 92.9%, Precision: 0.9291, Recall: 0.9286, F1-score: 0.9287, Avg loss: 0.206560
#
# Time 54.52
# Epoch 19
# -------------------------------
# Train loss 100th: 0.10  [   64/48000]
# Train loss 100th: 0.07  [ 6464/48000]
# Train loss 100th: 0.13  [12864/48000]
# Train loss 100th: 0.10  [19264/48000]
# Train loss 100th: 0.06  [25664/48000]
# Train loss 100th: 0.11  [32064/48000]
# Train loss 100th: 0.09  [38464/48000]
# Train loss 100th: 0.15  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 93.0%, Precision: 0.9300, Recall: 0.9297, F1-score: 0.9298, Avg loss: 0.200359
#
# Time 57.53
# Epoch 20
# -------------------------------
# Train loss 100th: 0.08  [   64/48000]
# Train loss 100th: 0.13  [ 6464/48000]
# Train loss 100th: 0.06  [12864/48000]
# Train loss 100th: 0.07  [19264/48000]
# Train loss 100th: 0.20  [25664/48000]
# Train loss 100th: 0.07  [32064/48000]
# Train loss 100th: 0.12  [38464/48000]
# Train loss 100th: 0.09  [44864/48000]
# Avg Train Loss: 0.09
# Test Metrics:
#  Accuracy: 92.8%, Precision: 0.9284, Recall: 0.9282, F1-score: 0.9283, Avg loss: 0.202637
#
# Time 60.6

# %%
for i, plot_buf in enumerate(list_plots):
    print(f'mode {i+1}')
    img = Image.open(plot_buf)
    display.display(img)
# Out:
# mode 1
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 2
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 3
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 4
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 5
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 6
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 7
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
# mode 8
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x400>
